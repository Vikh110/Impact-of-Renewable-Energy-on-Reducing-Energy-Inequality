# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv(r'C:\Users\vishw\Desktop\DATASET\Cleaned DATA\Access_to_Electricity_Percent.csv')

# %%
df1.head()
# Out:
#   GeoAreaName  TimePeriod  Access_to_Electricity_Percent  Time_Detail Location
# 0       World        2010                           95.9         2010    URBAN
# 1       World        2010                           83.6         2010  ALLAREA
# 2       World        2010                           72.9         2010    RURAL
# 3       World        2011                           74.3         2011    RURAL
# 4       World        2011                           84.6         2011  ALLAREA

# %%
df1  = df1.drop(columns = ['Time_Detail'])

# %%
df1.head()
# Out:
#   GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location
# 0       World        2010                           95.9    URBAN
# 1       World        2010                           83.6  ALLAREA
# 2       World        2010                           72.9    RURAL
# 3       World        2011                           74.3    RURAL
# 4       World        2011                           84.6  ALLAREA

# %%
df2 = pd.read_csv(r'C:\Users\vishw\Desktop\DATASET\Cleaned DATA\Intl_Financial_Flows_Clean_Energy_USD.csv')

# %%
df2.head()
# Out:
#   GeoAreaName  TimePeriod  Intl_Financial_Flows_Clean_Energy_USD  Time_Detail  \
# 0       World        2010                                2842.84         2010
# 1       World        2010                                   0.08         2010
# 2       World        2010                               11334.08         2010
# 3       World        2010                                1509.96         2010
# 4       World        2010                                 452.74         2010
#
#   Type of renewable technology
# 0                     MULTIPLE
# 1                       MARINE
# 2                          ALL
# 3                         WIND
# 4                        SOLAR

# %%
df2 = df2.drop(columns = ['Time_Detail'])

# %%
df2.head()
# Out:
#   GeoAreaName  TimePeriod  Intl_Financial_Flows_Clean_Energy_USD  \
# 0       World        2010                                2842.84
# 1       World        2010                                   0.08
# 2       World        2010                               11334.08
# 3       World        2010                                1509.96
# 4       World        2010                                 452.74
#
#   Type of renewable technology
# 0                     MULTIPLE
# 1                       MARINE
# 2                          ALL
# 3                         WIND
# 4                        SOLAR

# %%
df3 = pd.read_csv(r'C:\Users\vishw\Desktop\DATASET\Cleaned DATA\Renewable_Capacity_Watts_Per_Capita.csv')

# %%
df3.head()
# Out:
#   GeoAreaName  TimePeriod  Renewable_Capacity_Watts_Per_Capita  Time_Detail  \
# 0       World        2010                             25.92884         2010
# 1       World        2010                              5.95310         2010
# 2       World        2010                              9.46423         2010
# 3       World        2010                              1.41954         2010
# 4       World        2010                            132.53885         2010
#
#   Type of renewable technology
# 0                         WIND
# 1                        SOLAR
# 2                    BIOENERGY
# 3                   GEOTHERMAL
# 4                   HYDROPOWER

# %%
df3 = df3.drop(columns = ['Time_Detail'])

# %%
df3.head()
# Out:
#   GeoAreaName  TimePeriod  Renewable_Capacity_Watts_Per_Capita  \
# 0       World        2010                             25.92884
# 1       World        2010                              5.95310
# 2       World        2010                              9.46423
# 3       World        2010                              1.41954
# 4       World        2010                            132.53885
#
#   Type of renewable technology
# 0                         WIND
# 1                        SOLAR
# 2                    BIOENERGY
# 3                   GEOTHERMAL
# 4                   HYDROPOWER

# %%
df4 = pd.read_csv(r'C:\Users\vishw\Desktop\DATASET\Cleaned DATA\Renewable_Share_Total_Final_Energy_Consumption.csv')

# %%
df4.head()
# Out:
#   GeoAreaName  TimePeriod  Renewable_Share_TFEC
# 0       World        2010                 16.04
# 1       World        2011                 16.01
# 2       World        2012                 16.27
# 3       World        2013                 16.52
# 4       World        2014                 16.66

# %%
# Check columns and first few rows of each dataset
print("df1 columns:", df1.columns)
print(df1.head(), "\n")

print("df2 columns:", df2.columns)
print(df2.head(), "\n")

print("df3 columns:", df3.columns)
print(df3.head(), "\n")

print("df4 columns:", df4.columns)
print(df4.head(), "\n")

# Check unique values in GeoAreaName for each dataset
print("df1 unique regions:", df1['GeoAreaName'].unique())
print("\ndf2 unique regions:", df2['GeoAreaName'].unique())
print("\ndf3 unique regions:", df3['GeoAreaName'].unique())
print("\ndf4 unique regions:", df4['GeoAreaName'].unique())
# Out:
# df1 columns: Index(['GeoAreaName', 'TimePeriod', 'Access_to_Electricity_Percent',
#        'Location'],
#       dtype='object')
#   GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location
# 0       World        2010                           95.9    URBAN
# 1       World        2010                           83.6  ALLAREA
# 2       World        2010                           72.9    RURAL
# 3       World        2011                           74.3    RURAL
# 4       World        2011                           84.6  ALLAREA
#
# df2 columns: Index(['GeoAreaName', 'TimePeriod', 'Intl_Financial_Flows_Clean_Energy_USD',
#        'Type of renewable technology'],
#       dtype='object')
#   GeoAreaName  TimePeriod  Intl_Financial_Flows_Clean_Energy_USD  \
# 0       World        2010                                2842.84
# 1       World        2010                                   0.08
# 2       World        2010                               11334.08
# ...

# %%
# Standardize GeoAreaName in all datasets
for df in [df1, df2, df3, df4]:
    df['GeoAreaName'] = df['GeoAreaName'].str.strip()  # Remove extra spaces
    df['GeoAreaName'] = df['GeoAreaName'].str.title()  # Standardize case

# %%
# Define regions and countries of interest
regions_of_interest = [
    'Eastern Asia', 'Europe','South-Eastern Asia', 'Southern Asia',
    'Sub-Saharan Africa', 'Western Asia', 'World'
]

countries_of_interest = ['India', 'China']

# Filter each dataset
df1_filtered = df1[df1['GeoAreaName'].isin(regions_of_interest + countries_of_interest)]
df2_filtered = df2[df2['GeoAreaName'].isin(regions_of_interest + countries_of_interest)]
df3_filtered = df3[df3['GeoAreaName'].isin(regions_of_interest + countries_of_interest)]
df4_filtered = df4[df4['GeoAreaName'].isin(regions_of_interest + countries_of_interest)]

# %%
# Merge the filtered datasets using outer join
merged_df = df1_filtered.merge(df2_filtered, on=['GeoAreaName', 'TimePeriod'], how='outer')
merged_df = merged_df.merge(df3_filtered, on=['GeoAreaName', 'TimePeriod','Type of renewable technology'], how='outer')
final_df = merged_df.merge(df4_filtered, on=['GeoAreaName', 'TimePeriod'], how='outer')

# Inspect the merged dataset
print("Final dataset shape:", final_df.shape)
print(final_df.head())
# Out:
# Final dataset shape: (2808, 8)
#   GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location  \
# 0       China        2010                           99.7  ALLAREA
# 1       China        2010                           99.4    RURAL
# 2       China        2010                          100.0    URBAN
# 3       China        2010                           99.7  ALLAREA
# 4       China        2010                           99.4    RURAL
#
#    Intl_Financial_Flows_Clean_Energy_USD Type of renewable technology  \
# 0                                 143.76                          ALL
# 1                                 143.76                          ALL
# 2                                 143.76                          ALL
# 3                                  71.17                    BIOENERGY
# 4                                  71.17                    BIOENERGY
#
#    Renewable_Capacity_Watts_Per_Capita  Renewable_Share_TFEC
# ...

# %%
# Check missing values
print(final_df.isnull().sum())

# Inspect rows with missing values
print(final_df[final_df.isnull().any(axis=1)])
# Out:
# GeoAreaName                                0
# TimePeriod                                 0
# Access_to_Electricity_Percent              0
# Location                                   0
# Intl_Financial_Flows_Clean_Energy_USD      0
# Type of renewable technology               0
# Renewable_Capacity_Watts_Per_Capita      351
# Renewable_Share_TFEC                     216
# dtype: int64
#      GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location  \
# 15         China        2010                           99.7  ALLAREA
# 16         China        2010                           99.4    RURAL
# 17         China        2010                          100.0    URBAN
# 39         China        2011                          100.0    URBAN
# 40         China        2011                           99.8    RURAL
# ...          ...         ...                            ...      ...
# 2803       World        2022                           97.7    URBAN
# ...

# %%
final_df
# Out:
#      GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location  \
# 0          China        2010                           99.7  ALLAREA
# 1          China        2010                           99.4    RURAL
# 2          China        2010                          100.0    URBAN
# 3          China        2010                           99.7  ALLAREA
# 4          China        2010                           99.4    RURAL
# ...          ...         ...                            ...      ...
# 2803       World        2022                           97.7    URBAN
# 2804       World        2022                           84.0    RURAL
# 2805       World        2022                           91.4  ALLAREA
# 2806       World        2022                           97.7    URBAN
# 2807       World        2022                           84.0    RURAL
#
#       Intl_Financial_Flows_Clean_Energy_USD Type of renewable technology  \
# ...

# %%
final_df['Type of renewable technology'].fillna('Unknown', inplace=True)

# %%
final_df
# Out:
#      GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location  \
# 0          China        2010                           99.7  ALLAREA
# 1          China        2010                           99.4    RURAL
# 2          China        2010                          100.0    URBAN
# 3          China        2010                           99.7  ALLAREA
# 4          China        2010                           99.4    RURAL
# ...          ...         ...                            ...      ...
# 2803       World        2022                           97.7    URBAN
# 2804       World        2022                           84.0    RURAL
# 2805       World        2022                           91.4  ALLAREA
# 2806       World        2022                           97.7    URBAN
# 2807       World        2022                           84.0    RURAL
#
#       Intl_Financial_Flows_Clean_Energy_USD Type of renewable technology  \
# ...

# %%
# Fill missing values in Intl_Financial_Flows_Clean_Energy_USD with regional median
final_df['Intl_Financial_Flows_Clean_Energy_USD'] = final_df.groupby('GeoAreaName')[
    'Intl_Financial_Flows_Clean_Energy_USD'].transform(
    lambda x: x.fillna(x.median())
)

# Fill remaining NaNs with global median
final_df['Intl_Financial_Flows_Clean_Energy_USD'].fillna(
    final_df['Intl_Financial_Flows_Clean_Energy_USD'].median(), inplace=True
)

# %%
print(final_df.isnull().sum())
# Out:
# GeoAreaName                                0
# TimePeriod                                 0
# Access_to_Electricity_Percent              0
# Location                                   0
# Intl_Financial_Flows_Clean_Energy_USD      0
# Type of renewable technology               0
# Renewable_Capacity_Watts_Per_Capita      351
# Renewable_Share_TFEC                     216
# dtype: int64

# %%
# Step 1: Interpolate missing values within each region (linear interpolation over time)
final_df['Renewable_Share_TFEC'] = final_df.groupby('GeoAreaName')['Renewable_Share_TFEC'].transform(
    lambda x: x.interpolate(method='linear', limit_direction='both')
)

# Step 2: Fill remaining NaNs with regional median
final_df['Renewable_Share_TFEC'] = final_df.groupby('GeoAreaName')['Renewable_Share_TFEC'].transform(
    lambda x: x.fillna(x.median())
)

# Step 3: Fill remaining NaNs with global median (for regions with no data at all)
final_df['Renewable_Share_TFEC'].fillna(
    final_df['Renewable_Share_TFEC'].median(), inplace=True
)

# %%
print(final_df.isnull().sum())
# Out:
# GeoAreaName                                0
# TimePeriod                                 0
# Access_to_Electricity_Percent              0
# Location                                   0
# Intl_Financial_Flows_Clean_Energy_USD      0
# Type of renewable technology               0
# Renewable_Capacity_Watts_Per_Capita      351
# Renewable_Share_TFEC                       0
# dtype: int64

# %%
final_df.isnull().sum()
# Out:
# GeoAreaName                                0
# TimePeriod                                 0
# Access_to_Electricity_Percent              0
# Location                                   0
# Intl_Financial_Flows_Clean_Energy_USD      0
# Type of renewable technology               0
# Renewable_Capacity_Watts_Per_Capita      351
# Renewable_Share_TFEC                       0
# dtype: int64

# %%
final_df.head()
# Out:
#   GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location  \
# 0       China        2010                           99.7  ALLAREA
# 1       China        2010                           99.4    RURAL
# 2       China        2010                          100.0    URBAN
# 3       China        2010                           99.7  ALLAREA
# 4       China        2010                           99.4    RURAL
#
#    Intl_Financial_Flows_Clean_Energy_USD Type of renewable technology  \
# 0                                 143.76                          ALL
# 1                                 143.76                          ALL
# 2                                 143.76                          ALL
# 3                                  71.17                    BIOENERGY
# 4                                  71.17                    BIOENERGY
#
#    Renewable_Capacity_Watts_Per_Capita  Renewable_Share_TFEC
# 0                            173.01473                 12.26
# ...

# %%
final_df.tail()
# Out:
#      GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location  \
# 2803       World        2022                           97.7    URBAN
# 2804       World        2022                           84.0    RURAL
# 2805       World        2022                           91.4  ALLAREA
# 2806       World        2022                           97.7    URBAN
# 2807       World        2022                           84.0    RURAL
#
#       Intl_Financial_Flows_Clean_Energy_USD Type of renewable technology  \
# 2803                                5333.07                        SOLAR
# 2804                                5333.07                        SOLAR
# 2805                                1691.42                         WIND
# 2806                                1691.42                         WIND
# 2807                                1691.42                         WIND
#
#       Renewable_Capacity_Watts_Per_Capita  Renewable_Share_TFEC
# ...

# %%
final_df[final_df['GeoAreaName'] == 'World']
# Out:
#      GeoAreaName  TimePeriod  Access_to_Electricity_Percent Location  \
# 2496       World        2010                           95.9    URBAN
# 2497       World        2010                           83.6  ALLAREA
# 2498       World        2010                           72.9    RURAL
# 2499       World        2010                           95.9    URBAN
# 2500       World        2010                           83.6  ALLAREA
# ...          ...         ...                            ...      ...
# 2803       World        2022                           97.7    URBAN
# 2804       World        2022                           84.0    RURAL
# 2805       World        2022                           91.4  ALLAREA
# 2806       World        2022                           97.7    URBAN
# 2807       World        2022                           84.0    RURAL
#
#       Intl_Financial_Flows_Clean_Energy_USD Type of renewable technology  \
# ...

# %%
# Fill missing values in the Location column with "Unknown"
final_df['Location'] = final_df['Location'].fillna('Unknown')

# %%
# Fill missing Access_to_Electricity_Percent with regional median
final_df['Access_to_Electricity_Percent'] = final_df.groupby('GeoAreaName')[
    'Access_to_Electricity_Percent'
].transform(lambda x: x.fillna(x.median()))

# %%
# Fill missing Renewable_Capacity_Watts_Per_Capita with regional mean
final_df['Renewable_Capacity_Watts_Per_Capita'] = final_df.groupby('GeoAreaName')[
    'Renewable_Capacity_Watts_Per_Capita'
].transform(lambda x: x.fillna(x.mean()))

# %%
# Check for remaining missing values
print(final_df.isnull().sum())
# Out:
# GeoAreaName                              0
# TimePeriod                               0
# Access_to_Electricity_Percent            0
# Location                                 0
# Intl_Financial_Flows_Clean_Energy_USD    0
# Type of renewable technology             0
# Renewable_Capacity_Watts_Per_Capita      0
# Renewable_Share_TFEC                     0
# dtype: int64

# %% [markdown]
# * Filling Location with "Unknown" avoids introducing bias and ensures these rows remain usable for analysis.
# * Using median for Access_to_Electricity_Percent is robust to outliers and maintains the region-specific trends.
# * Using mean for Renewable_Capacity_Watts_Per_Capita smoothens gaps without drastic distortions.

# %%
# Rename columns for clarity
final_df.rename(
    columns={
        'GeoAreaName': 'Region',
        'TimePeriod': 'Year',
        'Access_to_Electricity_Percent': 'Electricity_Access_Percentage',
        'Location': 'Area_Type',
        'Intl_Financial_Flows_Clean_Energy_USD': 'Financial_Flows_Clean_Energy_USD',
        'Type of renewable technology': 'Renewable_Technology_Type',
        'Renewable_Capacity_Watts_Per_Capita': 'Renewable_Capacity_Per_Capita_Watts',
        'Renewable_Share_TFEC': 'Renewable_Share_in_TFEC_Percentage'
    },
    inplace=True
)

# %%
final_df
# Out:
#      Region  Year  Electricity_Access_Percentage Area_Type  \
# 0     China  2010                           99.7   ALLAREA
# 1     China  2010                           99.4     RURAL
# 2     China  2010                          100.0     URBAN
# 3     China  2010                           99.7   ALLAREA
# 4     China  2010                           99.4     RURAL
# ...     ...   ...                            ...       ...
# 2803  World  2022                           97.7     URBAN
# 2804  World  2022                           84.0     RURAL
# 2805  World  2022                           91.4   ALLAREA
# 2806  World  2022                           97.7     URBAN
# 2807  World  2022                           84.0     RURAL
#
#       Financial_Flows_Clean_Energy_USD Renewable_Technology_Type  \
# 0                               143.76                       ALL
# 1                               143.76                       ALL
# ...

# %%
final_df.to_csv(r'C:\Users\vishw\Desktop\DATASET\Cleaned_final_dataset.csv', index=False)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2808 entries, 0 to 2807
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Region                               2808 non-null   object
#  1   Year                                 2808 non-null   int64
#  2   Electricity_Access_Percentage        2808 non-null   float64
#  3   Area_Type                            2808 non-null   object
#  4   Financial_Flows_Clean_Energy_USD     2808 non-null   float64
#  5   Renewable_Technology_Type            2808 non-null   object
#  6   Renewable_Capacity_Per_Capita_Watts  2808 non-null   float64
#  7   Renewable_Share_in_TFEC_Percentage   2808 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 175.6+ KB

# %%
final_df.to_csv(r'C:\Users\vishw\Desktop\DATASET\Cleaned_final_dataset.csv', index=False)

# %%
# Check for duplicates in final_df
print("Number of duplicate rows before cleaning:", final_df.duplicated().sum())

# Remove duplicate rows
final_df = final_df.drop_duplicates()

# Confirm duplicates are removed
print("Number of duplicate rows after cleaning:", final_df.duplicated().sum())
# Out:
# Number of duplicate rows before cleaning: 0
# Number of duplicate rows after cleaning: 0

# %%
final_df
# Out:
#      Region  Year  Electricity_Access_Percentage Area_Type  \
# 0     China  2010                           99.7   Allarea
# 1     China  2010                           99.4     Rural
# 2     China  2010                          100.0     Urban
# 3     China  2010                           99.7   Allarea
# 4     China  2010                           99.4     Rural
# ...     ...   ...                            ...       ...
# 2803  World  2022                           97.7     Urban
# 2804  World  2022                           84.0     Rural
# 2805  World  2022                           91.4   Allarea
# 2806  World  2022                           97.7     Urban
# 2807  World  2022                           84.0     Rural
#
#       Financial_Flows_Clean_Energy_USD Renewable_Technology_Type  \
# 0                               143.76                       ALL
# 1                               143.76                       ALL
# ...

# %% [markdown]
# # ANALYSIS

# %%
# Descriptive Statistics

world_data = final_df[(final_df['Region'] == 'World')& (final_df['Renewable_Technology_Type'] == 'ALL')& (final_df['Area_Type'] == 'Allarea')]



print("Descriptive Statistics:")
print(world_data[['Electricity_Access_Percentage', 
                'Renewable_Capacity_Per_Capita_Watts', 
                'Renewable_Share_in_TFEC_Percentage', 
                'Financial_Flows_Clean_Energy_USD']].describe())

# Global Trends: Histograms
variables = ['Electricity_Access_Percentage', 
             'Renewable_Capacity_Per_Capita_Watts', 
             'Renewable_Share_in_TFEC_Percentage', 
             'Financial_Flows_Clean_Energy_USD']

for var in variables:
    plt.figure(figsize=(8, 5))
    sns.histplot(world_data[var], kde=True, bins=30, color='blue')
    plt.title(f"Global Distribution of {var.replace('_', ' ')}")
    plt.xlabel(var.replace('_', ' '))
    plt.ylabel("Frequency")
    plt.grid()
    plt.show()

# Boxplots for Variability
for var in variables:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=world_data[var], color='green')
    plt.title(f"Global Variability in {var.replace('_', ' ')}")
    plt.xlabel(var.replace('_', ' '))
    plt.grid()
    plt.show()
# Out:
# Descriptive Statistics:
#        Electricity_Access_Percentage  Renewable_Capacity_Per_Capita_Watts  \
# count                      13.000000                            13.000000
# mean                       87.923077                           279.296607
# std                         2.690153                            79.379456
# min                        83.600000                           175.340300
# 25%                        85.800000                           216.196170
# 50%                        88.200000                           268.458430
# 75%                        90.200000                           328.541860
# max                        91.400000                           424.140510
#
#        Renewable_Share_in_TFEC_Percentage  Financial_Flows_Clean_Energy_USD
# count                           13.000000                         13.000000
# mean                            17.206154                      15359.467692
# ...

# %%
# Descriptive Statistics : Regional Data including China and India

regional_data = final_df[(final_df['Region'] != 'World')& (final_df['Renewable_Technology_Type'] == 'ALL')& (final_df['Area_Type'] == 'Allarea')]

print("Basic Descriptive Statistics:")
descriptive_stats = regional_data[['Electricity_Access_Percentage', 
                              'Renewable_Capacity_Per_Capita_Watts', 
                              'Renewable_Share_in_TFEC_Percentage', 
                              'Financial_Flows_Clean_Energy_USD']].describe()

print(descriptive_stats)

# Visuals: Boxplots for variability
variables = ['Electricity_Access_Percentage', 
             'Renewable_Capacity_Per_Capita_Watts', 
             'Renewable_Share_in_TFEC_Percentage', 
             'Financial_Flows_Clean_Energy_USD']

for var in variables:
    plt.figure(figsize=(8, 5))
    sns.boxplot(y=regional_data[var], color='skyblue')
    plt.title(f"Regional Variability in {var.replace('_', ' ')}")
    plt.ylabel(var.replace('_', ' '))
    plt.grid(axis='y')
    plt.show()

# Visuals: Histograms for distribution
for var in variables:
    plt.figure(figsize=(8, 5))
    sns.histplot(regional_data[var], kde=True, bins=30, color='blue')
    plt.title(f"Regional Distribution of {var.replace('_', ' ')}")
    plt.xlabel(var.replace('_', ' '))
    plt.ylabel("Frequency")
    plt.grid(axis='y')
    plt.show()
# Out:
# Basic Descriptive Statistics:
#        Electricity_Access_Percentage  Renewable_Capacity_Per_Capita_Watts  \
# count                     104.000000                           104.000000
# mean                       88.513462                           253.745698
# std                        18.607860                           262.810814
# min                        33.200000                            23.646580
# 25%                        89.200000                            59.984313
# 50%                        96.250000                           129.758305
# 75%                        99.375000                           386.434687
# max                       100.000000                          1025.533100
#
#        Renewable_Share_in_TFEC_Percentage  Financial_Flows_Clean_Energy_USD
# count                          104.000000                        104.000000
# mean                            25.052885                       1405.037404
# ...

# %% [markdown]
# The frequency on the y-axis in the histograms represents the number of data points (regions, years, or entries in your dataset) that fall within a particular range (or bin) of the x-axis variable.
#
# Explanation:
#
# Bins on the X-Axis:
#
# The x-axis is divided into intervals or ranges (bins). For example, if the x-axis represents "Electricity Access Percentage," a bin might represent the range 70–80%.
#
# Frequency on the Y-Axis:
#
# The y-axis indicates how many data points fall within each bin.
#
# For example:
#
# If one bin is 70–80% electricity access, and the corresponding frequency is 500, it means 500 entries in the dataset have electricity access values between 70% and 80%.
#
# Visual Example:
#
# In the histogram for Electricity Access Percentage, you see:
#
# A high frequency near the bin for 100% electricity access, meaning most data points (regions or years) report nearly full electricity access.
#
# Lower frequencies for bins below 50%, showing fewer regions have low electricity access.

# %% [markdown]
# # EDA

# %% [markdown]
# # Rural vs Urban Electricity Access (2010–2022)

# %%
print(final_df["Area_Type"].unique())
# Out:
# ['Allarea' 'Rural' 'Urban']

# %%
rural_data = final_df[final_df["Area_Type"] == "Rural"]
urban_data = final_df[final_df["Area_Type"] == "Urban"]

print("Rural Data Sample:")
print(rural_data.head())
print("Urban Data Sample:")
print(urban_data.head())
# Out:
# Rural Data Sample:
#    Region  Year  Electricity_Access_Percentage Area_Type  \
# 1   China  2010                           99.4     Rural
# 4   China  2010                           99.4     Rural
# 7   China  2010                           99.4     Rural
# 10  China  2010                           99.4     Rural
# 13  China  2010                           99.4     Rural
#
#     Financial_Flows_Clean_Energy_USD Renewable_Technology_Type  \
# 1                             143.76                       ALL
# 4                              71.17                 BIOENERGY
# 7                               0.00                GEOTHERMAL
# 10                              0.00                HYDROPOWER
# 13                              0.00                    MARINE
#
#     Renewable_Capacity_Per_Capita_Watts  Renewable_Share_in_TFEC_Percentage
# 1                             173.01473                               12.26
# ...

# %%
# Standardize Area_Type to title case
final_df["Area_Type"] = final_df["Area_Type"].str.title()

# Check unique values again
print(final_df["Area_Type"].unique())

# Filter data
rural_data = final_df[final_df["Area_Type"] == "Rural"]
urban_data = final_df[final_df["Area_Type"] == "Urban"]

# Check filtered data
print("Rural Data Sample:")
print(rural_data.head())
print("Urban Data Sample:")
print(urban_data.head())
# Out:
# ['Allarea' 'Rural' 'Urban']
# Rural Data Sample:
#    Region  Year  Electricity_Access_Percentage Area_Type  \
# 1   China  2010                           99.4     Rural
# 4   China  2010                           99.4     Rural
# 7   China  2010                           99.4     Rural
# 10  China  2010                           99.4     Rural
# 13  China  2010                           99.4     Rural
#
#     Financial_Flows_Clean_Energy_USD Renewable_Technology_Type  \
# 1                             143.76                       ALL
# 4                              71.17                 BIOENERGY
# 7                               0.00                GEOTHERMAL
# 10                              0.00                HYDROPOWER
# 13                              0.00                    MARINE
#
#     Renewable_Capacity_Per_Capita_Watts  Renewable_Share_in_TFEC_Percentage
# 1                             173.01473                               12.26
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Filter the dataset for "Rural" and "Urban"
filtered_data = final_df[final_df["Area_Type"].isin(["Rural", "Urban"])]

# Unique regions
regions = filtered_data["Region"].unique()

# Iterate through each region and create plots
for region in regions:
    region_data = filtered_data[filtered_data["Region"] == region]
    
    # Bar Plot: Rural vs Urban Access to Electricity by Year
    plt.figure(figsize=(8, 6))
    sns.barplot(
        data=region_data,
        x="Year",
        y="Electricity_Access_Percentage",
        hue="Area_Type",
        palette="Set2"
    )
    plt.title(f"Rural vs Urban Electricity Access Percentage in {region}", fontsize=14)
    plt.xlabel("Year", fontsize=12)
    plt.ylabel("Access to Electricity Percentage", fontsize=12)
    # Adjust the y-axis range and ticks
    plt.ylim(60, 100)  # Ensure y-axis starts from 60 and ends at 100
    plt.yticks(range(60, 101, 2))  # Set y-axis ticks from 60 to 100 at intervals of 5
    plt.legend(title="Area Type", fontsize=10)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    
    # KDE Plot: Rural vs Urban Density of Electricity Access
    plt.figure(figsize=(8, 6))
    sns.kdeplot(
        data=region_data[region_data["Area_Type"] == "Rural"],
        x="Electricity_Access_Percentage",
        label="Rural",
        shade=True,
        color="blue"
    )
    sns.kdeplot(
        data=region_data[region_data["Area_Type"] == "Urban"],
        x="Electricity_Access_Percentage",
        label="Urban",
        shade=True,
        color="orange"
    )
    plt.title(f"Density of Electricity Access Percentage in {region}", fontsize=14)
    plt.xlabel("Access to Electricity Percentage", fontsize=12)
    plt.ylabel("Density", fontsize=12)
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()

# %%
# Filter the dataset for "World" and "All Areas"
world_data = final_df[(final_df['Region'] == 'World') & (final_df['Area_Type'] == 'Allarea')]

# Plot the line graph
plt.figure(figsize=(10, 6))
plt.plot(world_data['Year'], world_data['Electricity_Access_Percentage'], marker='o', color='blue', label='Access to Electricity (%)')

# Add labels and title
plt.title('Electricity Access Over Time (Worldwide)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Electricity Access Percentage', fontsize=12)

# Add grid and legend
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)

# Show the plot
plt.show()

# %%
# Filter the dataset for "World" and "All Areas"
world_data = final_df[(final_df['Region'] == 'World')]

# Plot the line graph
plt.figure(figsize=(10, 6))
plt.plot(world_data['Year'], world_data['Renewable_Share_in_TFEC_Percentage'], marker='x', color='green', label='Renewable Share in Total Final Energy Consumption')

# Add labels and title
plt.title('Renewable Share in Total Final Energy Consumption (Worldwide)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Renewable_Share_in_TFEC_Percentage', fontsize=12)

# Add grid and legend
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)

# Show the plot
plt.show()

# %%
# Filter the dataset for "World" and "All Areas"
world_data = final_df[(final_df['Region'] == 'World')& (final_df['Renewable_Technology_Type'] == 'ALL')]

# Plot the line graph
plt.figure(figsize=(10, 6))
plt.plot(world_data['Year'], world_data['Renewable_Capacity_Per_Capita_Watts'], marker='o', color='blue', label='Renewable_Capacity_Per_Capita_Watts')

# Add labels and title
plt.title('Renewable_Capacity_Per_Capita_Watts (Worldwide)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Renewable_Capacity_Per_Capita_Watts', fontsize=12)

# Add grid and legend
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)

# Show the plot
plt.show()

# %%
# Filter the dataset for "World" and "All Areas"
world_data = final_df[(final_df['Region'] == 'World')& (final_df['Renewable_Technology_Type'] == 'ALL')& (final_df['Area_Type'] == 'Allarea')]

# Plot the line graph
plt.figure(figsize=(10, 6))
plt.plot(world_data['Year'], world_data['Financial_Flows_Clean_Energy_USD'], marker='*', color='magenta', label='Financial_Flows_Clean_Energy_USD')

# Add labels and title
plt.title('Financial Flows towards Clean Energy in USD (Worldwide)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Financial_Flows_Clean_Energy_USD', fontsize=12)

# Add grid and legend
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)

# Show the plot
plt.show()

# %%
world_data = final_df[(final_df['Region'] == 'World') & (final_df['Area_Type'] != 'Allarea')]
plt.figure(figsize=(12, 8))
sns.barplot(
    data=world_data,
    x="Year",
    y="Electricity_Access_Percentage",
    hue="Area_Type",
    palette="Set2"
)
plt.title("Rural vs Urban Electricity Access Percentage (Worldwide)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Access to Electricity Percentage", fontsize=12)

# Adjust the y-axis range and ticks
plt.ylim(60, 100)  # Ensure y-axis starts from 60 and ends at 100
plt.yticks(range(60, 101, 5))  # Set y-axis ticks from 60 to 100 at intervals of 5

# Configure legend and x-axis labels
plt.legend(title="Area Type", fontsize=10)
plt.xticks(rotation=45)

# Adjust layout for clarity
plt.tight_layout()
plt.show()

# %%
world_data = final_df[(final_df['Region'] == 'World') & (final_df['Area_Type'] != 'Allarea')]
# KDE Plot: Density of Electricity Access (World Data)
plt.figure(figsize=(10, 6))

# KDE plot for Rural data
sns.kdeplot(
    data=world_data[world_data["Area_Type"] == "Rural"],
    x="Electricity_Access_Percentage",
    label="Rural",
    shade=True,
    color="blue"
)

# KDE plot for Urban data
sns.kdeplot(
    data=world_data[world_data["Area_Type"] == "Urban"],
    x="Electricity_Access_Percentage",
    label="Urban",
    shade=True,
    color="orange"
)

# Add labels, title, and legend
plt.title("Density of Electricity Access Percentage (World)", fontsize=14)
plt.xlabel("Access to Electricity Percentage", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.legend(title="Area Type", fontsize=10)  # Explicitly assign title to legend
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Filter the dataset to exclude "World"
filtered_data = final_df[
    (~final_df['Region'].isin(['World', 'India', 'China'])) &
    (final_df['Renewable_Technology_Type'] == 'ALL') &
    (final_df['Area_Type'] == 'Allarea')
]

# Initialize the plot
plt.figure(figsize=(14, 8))

# Define a clear and consistent color palette
palette = sns.color_palette("tab10", n_colors=filtered_data['Region'].nunique())

# Plot each region's data
for idx, region in enumerate(filtered_data['Region'].unique()):
    region_data = filtered_data[filtered_data['Region'] == region]
    plt.plot(
        region_data['Year'],
        region_data['Financial_Flows_Clean_Energy_USD'],
        label=region,
        marker='o',
        linewidth=2,
        color=palette[idx % len(palette)]
    )

# Add labels, title, and grid
plt.title('Financial Flows towards Clean Energy in USD (By Region)', fontsize=16, pad=20)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Financial Flows Clean Energy (USD)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot for clarity
plt.legend(
    fontsize=10, 
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5), 
    title="Regions"
)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # REGIONAL

# %%
# Filter the dataset to exclude "World"
filtered_data = final_df[
    (~final_df['Region'].isin(['World', 'India', 'China'])) &
    (final_df['Renewable_Technology_Type'] == 'ALL') &
    (final_df['Area_Type'] == 'Allarea')
]

# Initialize the plot
plt.figure(figsize=(14, 8))

# Define a clear and consistent color palette
palette = sns.color_palette("tab10", n_colors=filtered_data['Region'].nunique())

# Plot each region's data
for idx, region in enumerate(filtered_data['Region'].unique()):
    region_data = filtered_data[filtered_data['Region'] == region]
    plt.plot(
        region_data['Year'],
        region_data['Electricity_Access_Percentage'],
        label=region,
        marker='o',
        linewidth=2,
        color=palette[idx % len(palette)]
    )

# Add labels, title, and grid
plt.title('Overall Electricity_Access_Percentage (By Region)', fontsize=16, pad=20)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Overall Electricity_Access_Percentage', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot for clarity
plt.legend(
    fontsize=10, 
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5), 
    title="Regions"
)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the dataset to exclude "World"
filtered_data = final_df[
    (~final_df['Region'].isin(['World', 'India', 'China'])) &
    (final_df['Renewable_Technology_Type'] == 'ALL') &
    (final_df['Area_Type'] == 'Allarea')
]

# Initialize the plot
plt.figure(figsize=(14, 8))

# Define a clear and consistent color palette
palette = sns.color_palette("tab10", n_colors=filtered_data['Region'].nunique())

# Plot each region's data
for idx, region in enumerate(filtered_data['Region'].unique()):
    region_data = filtered_data[filtered_data['Region'] == region]
    plt.plot(
        region_data['Year'],
        region_data['Renewable_Share_in_TFEC_Percentage'],
        label=region,
        marker='o',
        linewidth=2,
        color=palette[idx % len(palette)]
    )

# Add labels, title, and grid
plt.title('Renewable Share in Total Final Energy Consumption Percentage (By Region)', fontsize=16, pad=20)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Renewable_Share_in_TFEC_Percentage', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot for clarity
plt.legend(
    fontsize=10, 
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5), 
    title="Regions"
)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter the dataset to exclude "World"
filtered_data = final_df[
    (~final_df['Region'].isin(['World', 'India', 'China'])) &
    (final_df['Renewable_Technology_Type'] == 'ALL') &
    (final_df['Area_Type'] == 'Allarea')
]

# Initialize the plot
plt.figure(figsize=(14, 8))

# Define a clear and consistent color palette
palette = sns.color_palette("tab10", n_colors=filtered_data['Region'].nunique())

# Plot each region's data
for idx, region in enumerate(filtered_data['Region'].unique()):
    region_data = filtered_data[filtered_data['Region'] == region]
    plt.plot(
        region_data['Year'],
        region_data['Renewable_Capacity_Per_Capita_Watts'],
        label=region,
        marker='o',
        linewidth=2,
        color=palette[idx % len(palette)]
    )

# Add labels, title, and grid
plt.title('Renewable Energy Capacity Watts per Capita (By Region)', fontsize=16, pad=20)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Renewable_Capacity_Per_Capita_Watts', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot for clarity
plt.legend(
    fontsize=10, 
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5), 
    title="Regions"
)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# final_df

# %%
final_df
# Out:
#      Region  Year  Electricity_Access_Percentage Area_Type  \
# 0     China  2010                           99.7   Allarea
# 1     China  2010                           99.4     Rural
# 2     China  2010                          100.0     Urban
# 3     China  2010                           99.7   Allarea
# 4     China  2010                           99.4     Rural
# ...     ...   ...                            ...       ...
# 2803  World  2022                           97.7     Urban
# 2804  World  2022                           84.0     Rural
# 2805  World  2022                           91.4   Allarea
# 2806  World  2022                           97.7     Urban
# 2807  World  2022                           84.0     Rural
#
#       Financial_Flows_Clean_Energy_USD Renewable_Technology_Type  \
# 0                               143.76                       ALL
# 1                               143.76                       ALL
# ...
